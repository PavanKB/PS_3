# %%
# Choose datasets that have less 50K instances and 20 features, to keep training times reasonable
# Choose a multivariate classification dataset
# Avoid datasets with missing  data. Do not need imputation
# Avoid imbalanced dataset to keep the metric to accuracy or f1

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from itertools import combinations, product

import matplotlib.pyplot as plt 

from sklearn.metrics import matthews_corrcoef
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.model_selection import cross_validate

from ucimlrepo import fetch_ucirepo 

# from utils import plot_decision_tree, plot_decision_surface, plot_feature_importance, plot_partial_dependence
from utils import get_data, get_df_details, plot_distrb

sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
X, y, metadata, variables = get_data('wine_quality')

# %%
X.shape
# Out:
# (6497, 11)

# %%
X_summary = get_df_details(X)
X_summary.merge(variables.set_index('name'), how='outer', left_index=True, right_index=True)
# Out:
#                        count        mean        std      min       25%  \
# alcohol               6497.0   10.491801   1.192712  8.00000   9.50000
# chlorides             6497.0    0.056034   0.035034  0.00900   0.03800
# citric_acid           6497.0    0.318633   0.145318  0.00000   0.25000
# color                    NaN         NaN        NaN      NaN       NaN
# density               6497.0    0.994697   0.002999  0.98711   0.99234
# fixed_acidity         6497.0    7.215307   1.296434  3.80000   6.40000
# free_sulfur_dioxide   6497.0   30.525319  17.749400  1.00000  17.00000
# pH                    6497.0    3.218501   0.160787  2.72000   3.11000
# quality                  NaN         NaN        NaN      NaN       NaN
# residual_sugar        6497.0    5.443235   4.757804  0.60000   1.80000
# sulphates             6497.0    0.531268   0.148806  0.22000   0.43000
# total_sulfur_dioxide  6497.0  115.744574  56.521855  6.00000  77.00000
# volatile_acidity      6497.0    0.339666   0.164636  0.08000   0.23000
#
#                             50%        75%        max  nunique  n_nulls  \
# alcohol                10.30000   11.30000   14.90000    111.0      0.0
# chlorides               0.04700    0.06500    0.61100    214.0      0.0
# citric_acid             0.31000    0.39000    1.66000     89.0      0.0
# color                       NaN        NaN        NaN      NaN      NaN
# density                 0.99489    0.99699    1.03898    998.0      0.0
# fixed_acidity           7.00000    7.70000   15.90000    106.0      0.0
# free_sulfur_dioxide    29.00000   41.00000  289.00000    135.0      0.0
# pH                      3.21000    3.32000    4.01000    108.0      0.0
# quality                     NaN        NaN        NaN      NaN      NaN
# residual_sugar          3.00000    8.10000   65.80000    316.0      0.0
# sulphates               0.51000    0.60000    2.00000    111.0      0.0
# total_sulfur_dioxide  118.00000  156.00000  440.00000    276.0      0.0
# volatile_acidity        0.29000    0.40000    1.58000    187.0      0.0
#
#                         dtype     role         type demographic  \
# alcohol               float64  Feature   Continuous        None
# chlorides             float64  Feature   Continuous        None
# citric_acid           float64  Feature   Continuous        None
# color                     NaN    Other  Categorical        None
# density               float64  Feature   Continuous        None
# fixed_acidity         float64  Feature   Continuous        None
# free_sulfur_dioxide   float64  Feature   Continuous        None
# pH                    float64  Feature   Continuous        None
# quality                   NaN   Target      Integer        None
# residual_sugar        float64  Feature   Continuous        None
# sulphates             float64  Feature   Continuous        None
# total_sulfur_dioxide  float64  Feature   Continuous        None
# volatile_acidity      float64  Feature   Continuous        None
#
#                                  description units missing_values
# alcohol                                 None  None             no
# chlorides                               None  None             no
# citric_acid                             None  None             no
# color                           red or white  None             no
# density                                 None  None             no
# fixed_acidity                           None  None             no
# free_sulfur_dioxide                     None  None             no
# pH                                      None  None             no
# quality               score between 0 and 10  None             no
# residual_sugar                          None  None             no
# sulphates                               None  None             no
# total_sulfur_dioxide                    None  None             no
# volatile_acidity                        None  None             no

# %%
idx = variables['type'].isin(['Integer', 'Continuous'])
int_cols = variables.loc[idx, 'name']
int_cols = int_cols.loc[~int_cols.isin(y.columns.tolist())]
int_cols
# Out:
# 0            fixed_acidity
# 1         volatile_acidity
# 2              citric_acid
# 3           residual_sugar
# 4                chlorides
# 5      free_sulfur_dioxide
# 6     total_sulfur_dioxide
# 7                  density
# 8                       pH
# 9                sulphates
# 10                 alcohol
# Name: name, dtype: object

# %%
# THERE IS NO COLOR COLUMN IN THE ACTUAL DATASET

idx = variables['type'].isin(['Categorical', 'Binary'])
cat_cols = variables.loc[idx, 'name']
cat_cols = cat_cols.loc[~cat_cols.isin(y.columns)]
cat_cols
# Out:
# 12    color
# Name: name, dtype: object

# %%
y.value_counts(normalize=True).plot(kind='bar', title='Wine Quality - 11 features, 6K+ rows', xlabel='Class', ylabel='%')
# Out:
# <Axes: title={'center': 'Wine Quality - 11 features, 6K+ rows'}, xlabel='Class', ylabel='%'>

# %% [markdown]
# # EDA - on the FULL data set
# 1. For the binary/Categorical value to a % plot of distribution
# 2. For the continuous/integer data - do a violin plot distribution
# 3. Do a correlation plot of the numeric series

# %%
X_eda = X.copy()

# %%
plot_distrb(X_eda)

# %%
sns.pairplot(X_eda, )

# %%
sns.heatmap(X_eda[int_cols].corr(),annot=True, fmt=".1f", vmin=-1, vmax = 1, cmap='vlag')
# Out:
# <Axes: >
